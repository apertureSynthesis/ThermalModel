# %%
import os,sys
sys.path.append(os.environ['HOME']+'/scripts')

from ThermalModel import *

# %%
stepOne = preProcessing(parFile='ThermalModel.par')
stepOne()
# Out:
# KRC File Header Information:
#
# Filename: /Users/nxroth/Desktop/asteroid-modeling/Thermal_fit-main/Ganymed/KRC/Ganymed_krc_temps.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      12   (48, 19, 7, 3, 100)   float32
#   1                1 ImageHDU         6   (48,)   float32
#   2                1 ImageHDU         7   (1, 19)   float32
#   3                1 ImageHDU         8   (1, 1, 7)   float32
#   4                1 ImageHDU         9   (1, 1, 1, 3)   float32
#   5                1 ImageHDU        10   (1, 1, 7, 1, 100)   float64
# None

# %%
stepTwo = radiativeTransfer(parFile='ThermalModel.par')
stepTwo()
